# %%
import scanpy as sc
import pandas as pd
import numpy as nu
from scipy.sparse import csr_matrix

from matplotlib import pyplot as plt
from matplotlib import rcParams
# %matplotlib inline

from score_function import clustering_score

# %%
sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=200, facecolor='white')

# %%
from scanpy import datasets

# %% [markdown]
# ## 3kPMMC dataset

# %%
adata = sc.read_h5ad("/shared/projects/spatial_cell_id_merfish/clustering_optimum/datasets/3kPBMC_data/processed_data.h5ad")

# %%
a = clustering_score(adata, score_value = 'calinski', min_res=0.1,max_res=2.5,step=0.1, plot=True, dim_reduction = 'pca')
# Out:
# Clustering by using the resolution 0.10, step 1 of 24
# Clustering by using the resolution 0.20, step 2 of 24
# Clustering by using the resolution 0.30, step 3 of 24
# Clustering by using the resolution 0.40, step 4 of 24
# Clustering by using the resolution 0.50, step 5 of 24
# Clustering by using the resolution 0.60, step 6 of 24
# Clustering by using the resolution 0.70, step 7 of 24
# Clustering by using the resolution 0.80, step 8 of 24
# Clustering by using the resolution 0.90, step 9 of 24
# Clustering by using the resolution 1.00, step 10 of 24
# Clustering by using the resolution 1.10, step 11 of 24
# Clustering by using the resolution 1.20, step 12 of 24
# Clustering by using the resolution 1.30, step 13 of 24
# Clustering by using the resolution 1.40, step 14 of 24
# Clustering by using the resolution 1.50, step 15 of 24
# Clustering by using the resolution 1.60, step 16 of 24
# Clustering by using the resolution 1.70, step 17 of 24
# Clustering by using the resolution 1.80, step 18 of 24
# Clustering by using the resolution 1.90, step 19 of 24
# Clustering by using the resolution 2.00, step 20 of 24
# Clustering by using the resolution 2.10, step 21 of 24
# Clustering by using the resolution 2.20, step 22 of 24
# Clustering by using the resolution 2.30, step 23 of 24
# Clustering by using the resolution 2.40, step 24 of 24

# %%
a = clustering_score(adata, score_value = 'bic', min_res=0.1,max_res=2.5,step=0.1, plot=True, dim_reduction = 'pca')
# Out:
# Clustering by using the resolution 0.10, step 1 of 24
# Clustering by using the resolution 0.20, step 2 of 24
# Clustering by using the resolution 0.30, step 3 of 24
# Clustering by using the resolution 0.40, step 4 of 24
# Clustering by using the resolution 0.50, step 5 of 24
# Clustering by using the resolution 0.60, step 6 of 24
# Clustering by using the resolution 0.70, step 7 of 24
# Clustering by using the resolution 0.80, step 8 of 24
# Clustering by using the resolution 0.90, step 9 of 24
# Clustering by using the resolution 1.00, step 10 of 24
# Clustering by using the resolution 1.10, step 11 of 24
# Clustering by using the resolution 1.20, step 12 of 24
# Clustering by using the resolution 1.30, step 13 of 24
# Clustering by using the resolution 1.40, step 14 of 24
# Clustering by using the resolution 1.50, step 15 of 24
# Clustering by using the resolution 1.60, step 16 of 24
# Clustering by using the resolution 1.70, step 17 of 24
# Clustering by using the resolution 1.80, step 18 of 24
# Clustering by using the resolution 1.90, step 19 of 24
# Clustering by using the resolution 2.00, step 20 of 24
# Clustering by using the resolution 2.10, step 21 of 24
# Clustering by using the resolution 2.20, step 22 of 24
# Clustering by using the resolution 2.30, step 23 of 24
# Clustering by using the resolution 2.40, step 24 of 24

# %%
sc.tl.leiden(adata, key_added="leiden_0.9", resolution=0.9)
sc.pl.umap(adata, color="leiden_0.9",legend_loc="on data")
# Out:
# /shared/home/ssarnata/.conda/envs/spatialdata/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ## neurons 2000 dataset (mouse brain)
# Info and reference: https://www.10xgenomics.com/resources/datasets/2-k-brain-cells-from-an-e-18-mouse-2-standard-2-1-0

# %%
adata = sc.read_h5ad("/shared/projects/spatial_cell_id_merfish/clustering_optimum/datasets/neurons_2000/processed_data.h5ad")

# %%
a = clustering_score(adata, score_value = 'calinski', min_res=0.1,max_res=2.5,step=0.1, plot=True, dim_reduction = 'pca')
# Out:
# Clustering by using the resolution 0.10, step 1 of 24
# Clustering by using the resolution 0.20, step 2 of 24
# Clustering by using the resolution 0.30, step 3 of 24
# Clustering by using the resolution 0.40, step 4 of 24
# Clustering by using the resolution 0.50, step 5 of 24
# Clustering by using the resolution 0.60, step 6 of 24
# Clustering by using the resolution 0.70, step 7 of 24
# Clustering by using the resolution 0.80, step 8 of 24
# Clustering by using the resolution 0.90, step 9 of 24
# Clustering by using the resolution 1.00, step 10 of 24
# Clustering by using the resolution 1.10, step 11 of 24
# Clustering by using the resolution 1.20, step 12 of 24
# Clustering by using the resolution 1.30, step 13 of 24
# Clustering by using the resolution 1.40, step 14 of 24
# Clustering by using the resolution 1.50, step 15 of 24
# Clustering by using the resolution 1.60, step 16 of 24
# Clustering by using the resolution 1.70, step 17 of 24
# Clustering by using the resolution 1.80, step 18 of 24
# Clustering by using the resolution 1.90, step 19 of 24
# Clustering by using the resolution 2.00, step 20 of 24
# Clustering by using the resolution 2.10, step 21 of 24
# Clustering by using the resolution 2.20, step 22 of 24
# Clustering by using the resolution 2.30, step 23 of 24
# Clustering by using the resolution 2.40, step 24 of 24

# %%
a[0]
# Out:
#     Calinski-Harabasz score  resolution  n_clus
# 0                -37.167063         0.1       4
# 1                -33.111453         0.2       5
# 2                -35.609607         0.3       5
# 3                -35.735411         0.4       5
# 4                -32.524054         0.5       6
# 5                -32.527657         0.6       6
# 6                -29.319631         0.7       7
# 7                -29.431425         0.8       7
# 8                -29.463596         0.9       7
# 9                -27.681012         1.0       8
# 10               -23.265024         1.1      10
# 11               -21.443212         1.2      11
# 12               -19.907802         1.3      12
# 13               -18.818071         1.4      13
# 14               -18.241667         1.5      16
# 15               -14.863149         1.6      17
# 16               -17.436941         1.7      17
# 17               -15.649238         1.8      19
# 18               -15.695033         1.9      19
# 19               -12.914840         2.0      20
# 20               -14.046496         2.1      22
# 21               -13.487091         2.2      23
# 22               -13.632274         2.3      24
# 23               -11.488065         2.4      23

# %%
b = clustering_score(adata, score_value = 'bic', min_res=0.1,max_res=2.5,step=0.1, plot=True, dim_reduction = 'pca')
# Out:
# Clustering by using the resolution 0.10, step 1 of 24
# Clustering by using the resolution 0.20, step 2 of 24
# Clustering by using the resolution 0.30, step 3 of 24
# Clustering by using the resolution 0.40, step 4 of 24
# Clustering by using the resolution 0.50, step 5 of 24
# Clustering by using the resolution 0.60, step 6 of 24
# Clustering by using the resolution 0.70, step 7 of 24
# Clustering by using the resolution 0.80, step 8 of 24
# Clustering by using the resolution 0.90, step 9 of 24
# Clustering by using the resolution 1.00, step 10 of 24
# Clustering by using the resolution 1.10, step 11 of 24
# Clustering by using the resolution 1.20, step 12 of 24
# Clustering by using the resolution 1.30, step 13 of 24
# Clustering by using the resolution 1.40, step 14 of 24
# Clustering by using the resolution 1.50, step 15 of 24
# Clustering by using the resolution 1.60, step 16 of 24
# Clustering by using the resolution 1.70, step 17 of 24
# Clustering by using the resolution 1.80, step 18 of 24
# Clustering by using the resolution 1.90, step 19 of 24
# Clustering by using the resolution 2.00, step 20 of 24
# Clustering by using the resolution 2.10, step 21 of 24
# Clustering by using the resolution 2.20, step 22 of 24
# Clustering by using the resolution 2.30, step 23 of 24
# Clustering by using the resolution 2.40, step 24 of 24

# %%
a[1]
# Out:
# (        BIC score  resolution  n_clus
#  0   347547.810465         0.1       4
#  1   347409.213712         0.2       5
#  2   347539.489745         0.3       5
#  3   346974.063099         0.4       5
#  4   345564.748117         0.5       6
#  5   345479.773585         0.6       6
#  6   344912.362026         0.7       7
#  7   344782.432480         0.8       7
#  8   344611.027936         0.9       7
#  9   343709.802293         1.0       8
#  10  343146.893652         1.1      10
#  11  345865.603565         1.2      11
#  12  345741.372622         1.3      12
#  13  345384.894848         1.4      13
#  14  345450.137439         1.5      16
#  15  346225.745130         1.6      17
#  16  343594.808550         1.7      17
#  17  346168.254202         1.8      19
#  18  346162.051707         1.9      19
#  19  347401.061140         2.0      20
#  20  346300.669514         2.1      22
#  21  345486.923813         2.2      23
#  22  345094.134839         2.3      24
#  23  347684.872583         2.4      23,
#  1.1)

# %%
sc.tl.leiden(adata, key_added="leiden_%s" %a[1], resolution=a[1])
sc.pl.umap(adata, color="leiden_%s" %a[1],legend_loc="on data", label = True)
# Out:
# /shared/home/ssarnata/.conda/envs/spatialdata/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
